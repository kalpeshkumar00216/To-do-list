# %%
class to_do_list() :
    def __init__(self):
        self.name = "kalpesh"
        
    def menu(self):
        press = input("""enter your number :
        if press 1 then open file,
        if press 2 then read file,
        if press 3 then write file,
        if press 4 then save file,
        if press 5 then delete columns,
        if press 6 then delete all columns """)
        
        if press == "1" :
            self.open_file()
        elif press == "2" :
            self.read_file()
        elif press == "3" :
            self.write_file()
        elif press == "4" :
            self.save_file()
        elif press == "5" :
            self.delete_columns()
        else:
            print("press valid number")

    def open_file(self):
        print("Welcome user")
        with open(r"C:\Users\kalpesh\OneDrive\Desktop\python.txt") as file:
            p = file.read()
            print(p)

    def read_file(self):
        print("read")
    def write_file(self):
        print("write")
    def save_file(self):
        print("save")
    def delete_columns(self):
        print("delete")

# %%
tdl = to_do_list()

# %%
# def opening():
# o = open(r"C:\Users\kalpesh\OneDrive\Desktop\python.txt")
# o.read()
# o.close()

# %%
# with open(r"C:\Users\kalpesh\OneDrive\Desktop\python.txt","w") as file:
#     file.write("hello, python!\n")
    # p = file.read()
    # print(p)

# %%
# with open(r"C:\Users\kalpesh\OneDrive\Desktop\python.txt") as file:
#     p = file.read()
#     print(p)
# Out:
# hello, python!

# %%
# if press == "1":
     # print("welcome user")
     # with open(r"C:\Users\kalpesh\OneDrive\Desktop\python.txt") as file:
     #     p = file.read()
     #     print(p)
